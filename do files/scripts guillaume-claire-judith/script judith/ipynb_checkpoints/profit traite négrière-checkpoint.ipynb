# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

#for algorythme which has to dowload the tstd and link missing information
import requests
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

# %%
##load data

# %%
#df_gd_venture=pd.read_csv(r'''C:\Users\Hannah\Documents\stage\slaveprofits2\Venture database GD.csv''')
#df_gd_cashflow=pd.read_csv(r'''C:\Users\Hannah\Documents\stage\slaveprofits2\Cash flow database GD.csv''')
#df_kr_venture=pd.read_csv(r'''C:\Users\Hannah\Documents\stage\slaveprofits2\Venture database KR - new.csv''')
#df_kr_cashflow=pd.read_csv(r'''C:\Users\Hannah\Documents\stage\slaveprofits2\Cash flow database KR - new.csv''')
#df_dr_venture=pd.read_csv(r'''C:\Users\Hannah\Documents\stage\slaveprofits2\Venture database DR.csv''')
#df_dr_cashflow=pd.read_csv(r'''C:\Users\Hannah\Documents\stage\slaveprofits2\Cash flow database DR.csv''')
df_gd_venture=pd.read_csv(r'''C:\Users\winer\Documents\judith\slaveprofits\Venture database GD.csv''')
df_gd_cashflow=pd.read_csv(r'''C:\Users\winer\Documents\judith\slaveprofits\Cash flow database GD.csv''')
df_kr_venture=pd.read_csv(r'''C:\Users\winer\Documents\judith\slaveprofits\Venture database KR - new.csv''')
df_dr_venture=pd.read_csv(r'''C:\Users\winer\Documents\judith\slaveprofits\Venture database DR.csv''')
df_kr_cashflow=pd.read_csv(r'''C:\Users\winer\Documents\judith\slaveprofits\Cash flow database KR - new.csv''')
df_dr_cashflow=pd.read_csv(r'''C:\Users\winer\Documents\judith\slaveprofits\Cash flow database DR.csv''')

# %% [markdown]
# ### correcting typo

# %%
df_gd_cashflow['value']=df_gd_cashflow['value'].replace(',','.',regex=True)
df_gd_cashflow.head(3)
# seems perfect!! ^^
# Out:
#    Line_number VentureID typeofcashflow  specification             value  \
# 0          1.0     GD001    Expenditure  Not specified  12235.7791666667
# 1          2.0     GD001    Expenditure  Not specified  654.854166666667
# 2          3.0     GD001    Expenditure  Not specified        17279.7875
#
#    meansofpaymentreturn  intermediarytradingoperation estimate  \
# 0                   NaN                           NaN      NaN
# 1                   NaN                           NaN      NaN
# 2                   NaN                           NaN      NaN
#
#   dateoftransaction            timing         currency remarks
# 0              1764        Outfitting  Livres tournois     NaN
# 1              1764  After Outfitting  Livres tournois     NaN
# 2              1765        Outfitting  Livres tournois     NaN

# %%
## looking at the missing values

# %%
df_gd_venture.isna().sum()
# Out:
# VentureID                                       0
# Type of venture                                 0
# Retranscriber                                   0
# Perspective of source                           0
# Nationality                                     0
# Source                                          0
# Date of primary source                         62
# Name of the ship                                0
# Name of the captain                            74
# Name of the owner or the outfitter             34
# Number of voyages                               0
# Internal crossref                             105
# Voyage-ID in TSTD                              18
# Place of outfitting                           117
# Place of purchase                              72
# Place of disembarkation                       116
# Date of departure from port of outfitting      92
# Date trade began in Africa                    112
# Date of departure from Africa                 117
# Date vessel arrived with slaves               117
# Date of return to port of outfitting          112
# Number of slaves purchased                    109
# Number of slaves sold                         102
# Share of the ship                              72
# Complete data on outlays?                      10
# Complete data on returns?                      10
# Profits reported in source                    117
# Various remarks                                62
# dtype: int64

# %%
#the most ennuying thing is probably when we miss values from "Voyage-ID in TSTD"
#du to the number of value from the slave-variable we miss, I think we won't be able to really treat many questions relative to that.

# %%
df_gd_cashflow.isna().sum()
# Out:
# Line_number                      221
# VentureID                          0
# typeofcashflow                     0
# specification                      6
# value                              0
# meansofpaymentreturn            1607
# intermediarytradingoperation    1607
# estimate                        1606
# dateoftransaction                445
# timing                             0
# currency                           0
# remarks                          519
# dtype: int64

# %%
#question: could we be able to get some informations about the fateoftransaction in the TSTD?
#

# %%
df_dr_venture.isna().sum()
# Out:
# VentureID                                      0
# Type of venture                                0
# Retranscriber                                  0
# Perspective of source                          0
# Nationality                                    0
# Source                                         0
# Date of primary source                        83
# Name of the ship                               0
# Name of the captain                           82
# Name of the owner or the outfitter             0
# Number of voyages                              0
# Internal crossref                             83
# Voyage-ID in TSTD                              0
# Place of outfitting                           83
# Place of purchase                              1
# Place of disembarkation                       83
# Date of departure from port of outfitting     14
# Date trade began in Africa                    83
# Date of departure from Africa                 83
# Date vessel arrived with slaves               83
# Date of return to port of outfitting          83
# Number of slaves purchased                    83
# Number of slaves sold                         83
# Share of the ship                              0
# Complete data on outlays?                      0
# Complete data on returns?                      0
# Profits reported in source                     0
# Various remarks                               75
# dtype: int64

# %%
df_dr_cashflow.isna().sum()
# Out:
# VentureID                         0
# typeofcashflow                    0
# specification                     0
# value                             0
# meansofpaymentreturn            548
# intermediarytradingoperation      0
# estimate                          0
# dateoftransaction               518
# timing                           39
# currency                          0
# remarks                         465
# dtype: int64

# %%
df_kr_venture.isna().sum()
# Out:
# VentureID                                      0
# Type of venture                                0
# Retranscriber                                  0
# Perspective of source                          0
# Nationality                                    0
# Source                                         0
# Date of primary source                        21
# Name of the ship                               1
# Name of the captain                           21
# Name of the owner or the outfitter             5
# Number of voyages                              0
# Internal crossref                              5
# Voyage-ID in TSTD                              2
# Place of outfitting                            1
# Place of purchase                             21
# Place of disembarkation                       21
# Date of departure from port of outfitting     11
# Date trade began in Africa                    19
# Date of departure from Africa                 11
# Date vessel arrived with slaves                3
# Date of return to port of outfitting          21
# Number of slaves purchased                     6
# Number of slaves sold                          6
# Share of the ship                              1
# Complete data on outlays?                      0
# Complete data on returns?                      0
# Profits reported in source                    21
# Various remarks                                5
# dtype: int64

# %%
df_dr_cashflow.isna().sum()
# Out:
# VentureID                         0
# typeofcashflow                    0
# specification                     0
# value                             0
# meansofpaymentreturn            548
# intermediarytradingoperation      0
# estimate                          0
# dateoftransaction               518
# timing                           39
# currency                          0
# remarks                         465
# dtype: int64

# %%
#we will have to download all the data of the TSTD, and to take informations to solve this issue of missing value. 
#I will have to do an algorithme for that. See work of Imrane Boucher

# %%
### merging

# %%
# join the three df of the centure
df_venture=pd.concat([df_dr_venture,df_gd_venture, df_kr_venture])
#ok
#join the three df of  the cashflow
df_cashflow=pd.concat([df_dr_cashflow,df_gd_cashflow, df_kr_cashflow])
df_venture.head(3)
#ok
# Out:
#   VentureID Type of venture                     Retranscriber  \
# 0     DR002          Voyage  David Richardson & Klas Rönnbäck
# 1     DR005          Voyage  David Richardson & Klas Rönnbäck
# 2     DR001          Voyage  David Richardson & Klas Rönnbäck
#
#   Perspective of source Nationality  \
# 0              Investor     English
# 1              Investor     English
# 2              Investor     English
#
#                                               Source Date of primary source  \
# 0  Chetham’s Library. Manchester. Nicholas Torre ...                    NaN
# 1  Chetham’s Library. Manchester. Nicholas Torre ...                    NaN
# 2  Chetham’s Library. Manchester. Nicholas Torre ...                    NaN
#
#   Name of the ship Name of the captain Name of the owner or the outfitter  \
# 0       Cumberland                 NaN                     Nicholas Torre
# 1       Cumberland        John Griffin                     Nicholas Torre
# 2         Frodsham                 NaN                     Nicholas Torre
#
#    ...  Date of departure from Africa Date vessel arrived with slaves  \
# 0  ...                            NaN                             NaN
# 1  ...                            NaN                             NaN
# 2  ...                            NaN                             NaN
#
#   Date of return to port of outfitting  Number of slaves purchased  \
# 0                                   NaN                        NaN
# 1                                   NaN                        NaN
# 2                                   NaN                        NaN
#
#   Number of slaves sold Share of the ship Complete data on outlays?  \
# 0                   NaN             0.083                       yes
# 1                   NaN             0.083                       yes
# 2                   NaN             0.125                       yes
#
#   Complete data on returns? Profits reported in source Various remarks
# 0                       yes                      11.52             NaN
# 1                       yes                       5.17             NaN
# 2                       yes                    -117.83             NaN
#
# [3 rows x 28 columns]

# %%
l=[intermediarytradingoperation,estimate,dateoftransation, Name of the captain,Place of outfitting ]
#idee! faire une liste des variables que l'on doit retrouver dans la Stdt
#donc: besoin de voir comment elles s'appellent: si nom different,; on ne pourra pas utilser algoritme prévu avec liste, et on ne pourra pas faire algo à boucle
#

def algo_stdt (document):
    for each var in df_venture['VentureID']:

# %%
#merge venture and cashflow
df_total=pd.merge(df_cashflow, df_venture, on="VentureID", how='inner')
df_total.head(45)
#ça m'a l'air d'etre bon!
# Out:
#    VentureID typeofcashflow        specification    value  \
# 0      DR001    Expenditure        Ship purchase      100
# 1      DR001    Expenditure            Insurance    30.15
# 2      DR001    Expenditure   Other expenditures   513.11
# 3      DR001         Return        Total returns   525.43
# 4      DR002    Expenditure    Trade cargo costs    88.36
# 5      DR002    Expenditure            Insurance     6.53
# 6      DR002    Expenditure   Other expenditures    140.9
# 7      DR002         Return        Total returns   247.31
# 8      DR003    Expenditure   Other expenditures  1018.92
# 9      DR003    Expenditure   Other expenditures   410.59
# 10     DR003    Expenditure            Insurance    44.33
# 11     DR003         Return        Sale of sugar   745.32
# 12     DR003         Return         Other return   799.49
# 13     DR004    Expenditure     Outfitting costs       60
# 14     DR004    Expenditure    Trade cargo costs   389.89
# 15     DR004    Expenditure   Other expenditures     79.1
# 16     DR004         Return   Insurance payments      7.5
# 17     DR004         Return        Sale of sugar   183.73
# 18     DR004         Return    Bills of exchange   245.15
# 19     DR004         Return         Other return   119.61
# 20     DR005    Expenditure    Total expenditure   371.93
# 21     DR005         Return        Total returns    377.1
# 22     DR006    Expenditure    Trade cargo costs   407.42
# 23     DR006    Expenditure   Other expenditures   380.41
# 24     DR006         Return        Total returns   916.91
# 25     DR007    Expenditure     Outfitting costs      200
# 26     DR007    Expenditure    Trade cargo costs  1486.79
# 27     DR007    Expenditure            Insurance    48.38
# 28     DR007    Expenditure   Other expenditures   132.34
# 29     DR007         Return        Total returns  1483.12
# 30     DR008    Expenditure    Trade cargo costs   627.38
# 31     DR008    Expenditure            Insurance    25.95
# 32     DR008    Expenditure   Other expenditures    93.45
# 33     DR008         Return        Sale of sugar   316.49
# 34     DR008         Return       Sale of cotton    97.11
# 35     DR008         Return         Other return   343.53
# 36     DR009    Expenditure    Trade cargo costs  1142.58
# 37     DR009    Expenditure            Insurance    36.16
# 38     DR009    Expenditure   Other expenditures   503.46
# 39     DR009         Return          Sale of rum     8.08
# 40     DR009         Return         Other return  1909.27
# 41     DR010    Expenditure    Trade cargo costs   502.84
# 42     DR010    Expenditure            Insurance    23.33
# 43     DR010    Expenditure   Other expenditures   352.65
# 44     DR010         Return  Sale of other goods   224.25
#
#    meansofpaymentreturn  intermediarytradingoperation estimate  \
# 0                   NaN                           0.0        0
# 1                   NaN                           0.0        0
# 2                   NaN                           0.0        1
# 3                   NaN                           0.0        1
# 4                Credit                           0.0        0
# 5                   NaN                           0.0        0
# 6                   NaN                           0.0        1
# 7                   NaN                           0.0        1
# 8                Credit                           0.0        0
# 9                   NaN                           0.0        1
# 10                  NaN                           0.0        0
# 11                  NaN                           0.0        0
# 12                  NaN                           0.0        1
# 13                  NaN                           0.0        0
# 14               Credit                           0.0        0
# 15                  NaN                           0.0        1
# 16                  NaN                           0.0        0
# 17                  NaN                           0.0        0
# 18                  NaN                           0.0        0
# 19                  NaN                           0.0        1
# 20                  NaN                           0.0        0
# 21                  NaN                           0.0        1
# 22               Credit                           0.0        0
# 23                  NaN                           0.0        1
# 24                  NaN                           0.0        1
# 25                  NaN                           0.0        0
# 26               Credit                           0.0        0
# 27                  NaN                           0.0        0
# 28                  NaN                           0.0        1
# 29                  NaN                           0.0        1
# 30               Credit                           0.0        0
# 31                  NaN                           0.0        0
# 32                  NaN                           0.0        1
# 33                  NaN                           0.0        0
# 34                  NaN                           0.0        0
# 35                  NaN                           0.0        1
# 36               Credit                           0.0        0
# 37                  NaN                           0.0        0
# 38                  NaN                           0.0        1
# 39                  NaN                           0.0        0
# 40                  NaN                           0.0        1
# 41               Credit                           0.0        0
# 42                  NaN                           0.0        0
# 43                  NaN                           0.0        1
# 44                  NaN                           0.0        0
#
#    dateoftransaction      timing        currency  ...  \
# 0         1750-09-26         NaN  Pound sterling  ...
# 1         1750-09-26         NaN  Pound sterling  ...
# 2         1750-09-26         NaN  Pound sterling  ...
# 3         1753-02-23         NaN  Pound sterling  ...
# 4                NaN  Outfitting  Pound sterling  ...
# 5                NaN  Outfitting  Pound sterling  ...
# 6                NaN  Outfitting  Pound sterling  ...
# 7         1755-08-12         NaN  Pound sterling  ...
# 8                NaN  Outfitting  Pound sterling  ...
# 9                NaN  Outfitting  Pound sterling  ...
# 10               NaN  Outfitting  Pound sterling  ...
# 11        1756-04-03         NaN  Pound sterling  ...
# 12        1756-04-03         NaN  Pound sterling  ...
# 13               NaN  Outfitting  Pound sterling  ...
# 14               NaN  Outfitting  Pound sterling  ...
# 15               NaN  Outfitting  Pound sterling  ...
# 16               NaN      Return  Pound sterling  ...
# 17        1755-02-20         NaN  Pound sterling  ...
# 18        1755-02-20         NaN  Pound sterling  ...
# 19        1755-02-20         NaN  Pound sterling  ...
# 20               NaN  Outfitting  Pound sterling  ...
# 21        1753-11-10         NaN  Pound sterling  ...
# 22        1751-06-08         NaN  Pound sterling  ...
# 23        1751-06-08         NaN  Pound sterling  ...
# 24        1753-11-10         NaN  Pound sterling  ...
# 25              1755         NaN  Pound sterling  ...
# 26              1755         NaN  Pound sterling  ...
# 27              1755         NaN  Pound sterling  ...
# 28              1755         NaN  Pound sterling  ...
# 29        1759-11-12         NaN  Pound sterling  ...
# 30               NaN  Outfitting  Pound sterling  ...
# 31               NaN  Outfitting  Pound sterling  ...
# 32               NaN  Outfitting  Pound sterling  ...
# 33               NaN      Return  Pound sterling  ...
# 34               NaN      Return  Pound sterling  ...
# 35               NaN      Return  Pound sterling  ...
# 36        1753-09-21         NaN  Pound sterling  ...
# 37        1753-05-22         NaN  Pound sterling  ...
# 38        1753-05-22         NaN  Pound sterling  ...
# 39        1755-02-20         NaN  Pound sterling  ...
# 40        1755-02-20         NaN  Pound sterling  ...
# 41        1752-02-13         NaN  Pound sterling  ...
# 42        1752-02-13         NaN  Pound sterling  ...
# 43        1752-02-13         NaN  Pound sterling  ...
# 44        1755-02-20         NaN  Pound sterling  ...
#
#    Date of departure from Africa  Date vessel arrived with slaves  \
# 0                            NaN                              NaN
# 1                            NaN                              NaN
# 2                            NaN                              NaN
# 3                            NaN                              NaN
# 4                            NaN                              NaN
# 5                            NaN                              NaN
# 6                            NaN                              NaN
# 7                            NaN                              NaN
# 8                            NaN                              NaN
# 9                            NaN                              NaN
# 10                           NaN                              NaN
# 11                           NaN                              NaN
# 12                           NaN                              NaN
# 13                           NaN                              NaN
# 14                           NaN                              NaN
# 15                           NaN                              NaN
# 16                           NaN                              NaN
# 17                           NaN                              NaN
# 18                           NaN                              NaN
# 19                           NaN                              NaN
# 20                           NaN                              NaN
# 21                           NaN                              NaN
# 22                           NaN                              NaN
# 23                           NaN                              NaN
# 24                           NaN                              NaN
# 25                           NaN                              NaN
# 26                           NaN                              NaN
# 27                           NaN                              NaN
# 28                           NaN                              NaN
# 29                           NaN                              NaN
# 30                           NaN                              NaN
# 31                           NaN                              NaN
# 32                           NaN                              NaN
# 33                           NaN                              NaN
# 34                           NaN                              NaN
# 35                           NaN                              NaN
# 36                           NaN                              NaN
# 37                           NaN                              NaN
# 38                           NaN                              NaN
# 39                           NaN                              NaN
# 40                           NaN                              NaN
# 41                           NaN                              NaN
# 42                           NaN                              NaN
# 43                           NaN                              NaN
# 44                           NaN                              NaN
#
#    Date of return to port of outfitting  Number of slaves purchased  \
# 0                                    NaN                        NaN
# 1                                    NaN                        NaN
# 2                                    NaN                        NaN
# 3                                    NaN                        NaN
# 4                                    NaN                        NaN
# 5                                    NaN                        NaN
# 6                                    NaN                        NaN
# 7                                    NaN                        NaN
# 8                                    NaN                        NaN
# 9                                    NaN                        NaN
# 10                                   NaN                        NaN
# 11                                   NaN                        NaN
# 12                                   NaN                        NaN
# 13                                   NaN                        NaN
# 14                                   NaN                        NaN
# 15                                   NaN                        NaN
# 16                                   NaN                        NaN
# 17                                   NaN                        NaN
# 18                                   NaN                        NaN
# 19                                   NaN                        NaN
# 20                                   NaN                        NaN
# 21                                   NaN                        NaN
# 22                                   NaN                        NaN
# 23                                   NaN                        NaN
# 24                                   NaN                        NaN
# 25                                   NaN                        NaN
# 26                                   NaN                        NaN
# 27                                   NaN                        NaN
# 28                                   NaN                        NaN
# 29                                   NaN                        NaN
# 30                                   NaN                        NaN
# 31                                   NaN                        NaN
# 32                                   NaN                        NaN
# 33                                   NaN                        NaN
# 34                                   NaN                        NaN
# 35                                   NaN                        NaN
# 36                                   NaN                        NaN
# 37                                   NaN                        NaN
# 38                                   NaN                        NaN
# 39                                   NaN                        NaN
# 40                                   NaN                        NaN
# 41                                   NaN                        NaN
# 42                                   NaN                        NaN
# 43                                   NaN                        NaN
# 44                                   NaN                        NaN
#
#    Number of slaves sold Share of the ship Complete data on outlays?  \
# 0                    NaN             0.125                       yes
# 1                    NaN             0.125                       yes
# 2                    NaN             0.125                       yes
# 3                    NaN             0.125                       yes
# 4                    NaN             0.083                       yes
# 5                    NaN             0.083                       yes
# 6                    NaN             0.083                       yes
# 7                    NaN             0.083                       yes
# 8                    NaN              0.25                       yes
# 9                    NaN              0.25                       yes
# 10                   NaN              0.25                       yes
# 11                   NaN              0.25                       yes
# 12                   NaN              0.25                       yes
# 13                   NaN             0.125                       yes
# 14                   NaN             0.125                       yes
# 15                   NaN             0.125                       yes
# 16                   NaN             0.125                       yes
# 17                   NaN             0.125                       yes
# 18                   NaN             0.125                       yes
# 19                   NaN             0.125                       yes
# 20                   NaN             0.083                       yes
# 21                   NaN             0.083                       yes
# 22                   NaN              0.17                       yes
# 23                   NaN              0.17                       yes
# 24                   NaN              0.17                       yes
# 25                   NaN             0.375                       yes
# 26                   NaN             0.375                       yes
# 27                   NaN             0.375                       yes
# 28                   NaN             0.375                       yes
# 29                   NaN             0.375                       yes
# 30                   NaN              0.17                       yes
# 31                   NaN              0.17                       yes
# 32                   NaN              0.17                       yes
# 33                   NaN              0.17                       yes
# 34                   NaN              0.17                       yes
# 35                   NaN              0.17                       yes
# 36                   NaN             0.375                       yes
# 37                   NaN             0.375                       yes
# 38                   NaN             0.375                       yes
# 39                   NaN             0.375                       yes
# 40                   NaN             0.375                       yes
# 41                   NaN             0.125                       yes
# 42                   NaN             0.125                       yes
# 43                   NaN             0.125                       yes
# 44                   NaN             0.125                       yes
#
#    Complete data on returns? Profits reported in source Various remarks
# 0                        yes                    -117.83             NaN
# 1                        yes                    -117.83             NaN
# 2                        yes                    -117.83             NaN
# 3                        yes                    -117.83             NaN
# 4                        yes                      11.52             NaN
# 5                        yes                      11.52             NaN
# 6                        yes                      11.52             NaN
# 7                        yes                      11.52             NaN
# 8                        yes                      70.97             NaN
# 9                        yes                      70.97             NaN
# 10                       yes                      70.97             NaN
# 11                       yes                      70.97             NaN
# 12                       yes                      70.97             NaN
# 13                       yes                      27.20             NaN
# 14                       yes                      27.20             NaN
# 15                       yes                      27.20             NaN
# 16                       yes                      27.20             NaN
# 17                       yes                      27.20             NaN
# 18                       yes                      27.20             NaN
# 19                       yes                      27.20             NaN
# 20                       yes                       5.17             NaN
# 21                       yes                       5.17             NaN
# 22                       yes                     129.08             NaN
# 23                       yes                     129.08             NaN
# 24                       yes                     129.08             NaN
# 25                       yes                    -384.39             NaN
# 26                       yes                    -384.39             NaN
# 27                       yes                    -384.39             NaN
# 28                       yes                    -384.39             NaN
# 29                       yes                    -384.39             NaN
# 30                       yes                      10.35             NaN
# 31                       yes                      10.35             NaN
# 32                       yes                      10.35             NaN
# 33                       yes                      10.35             NaN
# 34                       yes                      10.35             NaN
# 35                       yes                      10.35             NaN
# 36                       yes                     227.07             NaN
# 37                       yes                     227.07             NaN
# 38                       yes                     227.07             NaN
# 39                       yes                     227.07             NaN
# 40                       yes                     227.07             NaN
# 41                       yes                     198.03             NaN
# 42                       yes                     198.03             NaN
# 43                       yes                     198.03             NaN
# 44                       yes                     198.03             NaN
#
# [45 rows x 39 columns]
